# %%
import numpy as np
import pandas as pd

# %%
# Out:
#   Cell In[2], line 1
#     pd.read_csv(\Users\anura\Downloads\SuperMarket Analysis.csv")
#                  ^
# SyntaxError: unexpected character after line continuation character
