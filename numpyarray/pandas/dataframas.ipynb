# %%
import numpy as np
import pandas as pd

# %% [markdown]
# creating a dataframes

# %%
data={
    'Name':['anurag','sujal','pawan','aman'],
    'age':[10,20,30,40],
    'City':['mau','ghazipur','raipur','mardah'],
    'Salary':[65000,75000,85000,90000]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#      Name  age      City  Salary
# 0  anurag   10       mau   65000
# 1   sujal   20  ghazipur   75000
# 2   pawan   30    raipur   85000
# 3    aman   40    mardah   90000

# %% [markdown]
# selactions and indxing of columns

# %%
df['Name']
# Out:
# 0    anurag
# 1     sujal
# 2     pawan
# 3      aman
# Name: Name, dtype: object

# %%
df[["City","Name"]]
# Out:
#        City    Name
# 0       mau  anurag
# 1  ghazipur   sujal
# 2    raipur   pawan
# 3    mardah    aman

# %% [markdown]
# creating a new columns

# %%
df["Designation"]=["dr.","eng.","lo.","dr."]
df
# Out:
#      Name  age      City  Salary Designation
# 0  anurag   10       mau   65000         dr.
# 1   sujal   20  ghazipur   75000        eng.
# 2   pawan   30    raipur   85000         lo.
# 3    aman   40    mardah   90000         dr.

# %% [markdown]
# remove a columns

# %%
df.drop("Designation",axis=1,inplace=True)

# %%
df
# Out:
#      Name  age      City  Salary
# 0  anurag   10       mau   65000
# 1   sujal   20  ghazipur   75000
# 2   pawan   30    raipur   85000
# 3    aman   40    mardah   90000

# %%
df.drop(["City","Salary"],axis=1)
# Out:
#      Name  age
# 0  anurag   10
# 1   sujal   20
# 2   pawan   30
# 3    aman   40

# %%
df
# Out:
#      Name  age      City  Salary
# 0  anurag   10       mau   65000
# 1   sujal   20  ghazipur   75000
# 2   pawan   30    raipur   85000
# 3    aman   40    mardah   90000

# %%
df.drop(0,axis=0)
# Out:
#     Name  age      City  Salary
# 1  sujal   20  ghazipur   75000
# 2  pawan   30    raipur   85000
# 3   aman   40    mardah   90000

# %%
 df.loc[0]
# Out:
# Name      anurag
# age           10
# City         mau
# Salary     65000
# Name: 0, dtype: object

# %% [markdown]
# selecting subaets of  rows and colomuns

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0       mau   65000
# 1  ghazipur   75000

# %%
df.loc[[1,2]][["City","Salary"]]
# Out:
#        City  Salary
# 1  ghazipur   75000
# 2    raipur   85000

# %% [markdown]
# conditions

# %%
df
# Out:
#      Name  age      City  Salary
# 0  anurag   10       mau   65000
# 1   sujal   20  ghazipur   75000
# 2   pawan   30    raipur   85000
# 3    aman   40    mardah   90000

# %%
df[(df["age"]>=30) & (["City"]=="raipur")]
# Out:
# Empty DataFrame
# Columns: [Name, age, City, Salary]
# Index: []

# %% [markdown]
# missing data

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %% [markdown]
# removing missing data

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna(thresh=4)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 df.fillna(thresh=1)
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'thresh'

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
Values ={}
